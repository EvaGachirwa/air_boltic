# %%
import pandas as pd

# %%
df = pd.read_json('../data/aeroplane_model.json')

# %%
df
# Out:
#                                                               Boeing  \
# 737-800            {'max_seats': 189, 'max_weight': 79015, 'max_d...
# 777-300ER          {'max_seats': 396, 'max_weight': 351535, 'max_...
# 787-9              {'max_seats': 296, 'max_weight': 254000, 'max_...
# A320neo                                                          NaN
# A350-900                                                         NaN
# A380-800                                                         NaN
# E190-E2                                                          NaN
# E175                                                             NaN
# E195-E2                                                          NaN
# CRJ900                                                           NaN
# Q400                                                             NaN
# Citation X+                                                      NaN
# Citation Latitude                                                NaN
# G650                                                             NaN
# G550                                                             NaN
# Falcon 7X                                                        NaN
# Falcon 2000LXS                                                   NaN
# SpaceJet M90                                                     NaN
# C919                                                             NaN
#
#                                                               Airbus  \
# 737-800                                                          NaN
# 777-300ER                                                        NaN
# 787-9                                                            NaN
# A320neo            {'max_seats': 194, 'max_weight': 79000, 'max_d...
# A350-900           {'max_seats': 440, 'max_weight': 280000, 'max_...
# A380-800           {'max_seats': 853, 'max_weight': 560000, 'max_...
# E190-E2                                                          NaN
# E175                                                             NaN
# E195-E2                                                          NaN
# CRJ900                                                           NaN
# Q400                                                             NaN
# Citation X+                                                      NaN
# Citation Latitude                                                NaN
# G650                                                             NaN
# G550                                                             NaN
# Falcon 7X                                                        NaN
# Falcon 2000LXS                                                   NaN
# SpaceJet M90                                                     NaN
# C919                                                             NaN
#
#                                                              Embraer  \
# 737-800                                                          NaN
# 777-300ER                                                        NaN
# 787-9                                                            NaN
# A320neo                                                          NaN
# A350-900                                                         NaN
# A380-800                                                         NaN
# E190-E2            {'max_seats': 114, 'max_weight': 56600, 'max_d...
# E175               {'max_seats': 88, 'max_weight': 37500, 'max_di...
# E195-E2            {'max_seats': 146, 'max_weight': 61700, 'max_d...
# CRJ900                                                           NaN
# Q400                                                             NaN
# Citation X+                                                      NaN
# Citation Latitude                                                NaN
# G650                                                             NaN
# G550                                                             NaN
# Falcon 7X                                                        NaN
# Falcon 2000LXS                                                   NaN
# SpaceJet M90                                                     NaN
# C919                                                             NaN
#
#                                                           Bombardier  \
# 737-800                                                          NaN
# 777-300ER                                                        NaN
# 787-9                                                            NaN
# A320neo                                                          NaN
# A350-900                                                         NaN
# A380-800                                                         NaN
# E190-E2                                                          NaN
# E175                                                             NaN
# E195-E2                                                          NaN
# CRJ900             {'max_seats': 90, 'max_weight': 38530, 'max_di...
# Q400               {'max_seats': 90, 'max_weight': 29257, 'max_di...
# Citation X+                                                      NaN
# Citation Latitude                                                NaN
# G650                                                             NaN
# G550                                                             NaN
# Falcon 7X                                                        NaN
# Falcon 2000LXS                                                   NaN
# SpaceJet M90                                                     NaN
# C919                                                             NaN
#
#                                                               Cessna  \
# 737-800                                                          NaN
# 777-300ER                                                        NaN
# 787-9                                                            NaN
# A320neo                                                          NaN
# A350-900                                                         NaN
# A380-800                                                         NaN
# E190-E2                                                          NaN
# E175                                                             NaN
# E195-E2                                                          NaN
# CRJ900                                                           NaN
# Q400                                                             NaN
# Citation X+        {'max_seats': 12, 'max_weight': 16555, 'max_di...
# Citation Latitude  {'max_seats': 9, 'max_weight': 13605, 'max_dis...
# G650                                                             NaN
# G550                                                             NaN
# Falcon 7X                                                        NaN
# Falcon 2000LXS                                                   NaN
# SpaceJet M90                                                     NaN
# C919                                                             NaN
#
#                                                           Gulfstream  \
# 737-800                                                          NaN
# 777-300ER                                                        NaN
# 787-9                                                            NaN
# A320neo                                                          NaN
# A350-900                                                         NaN
# A380-800                                                         NaN
# E190-E2                                                          NaN
# E175                                                             NaN
# E195-E2                                                          NaN
# CRJ900                                                           NaN
# Q400                                                             NaN
# Citation X+                                                      NaN
# Citation Latitude                                                NaN
# G650               {'max_seats': 19, 'max_weight': 45360, 'max_di...
# G550               {'max_seats': 19, 'max_weight': 41300, 'max_di...
# Falcon 7X                                                        NaN
# Falcon 2000LXS                                                   NaN
# SpaceJet M90                                                     NaN
# C919                                                             NaN
#
#                                                             Dassault  \
# 737-800                                                          NaN
# 777-300ER                                                        NaN
# 787-9                                                            NaN
# A320neo                                                          NaN
# A350-900                                                         NaN
# A380-800                                                         NaN
# E190-E2                                                          NaN
# E175                                                             NaN
# E195-E2                                                          NaN
# CRJ900                                                           NaN
# Q400                                                             NaN
# Citation X+                                                      NaN
# Citation Latitude                                                NaN
# G650                                                             NaN
# G550                                                             NaN
# Falcon 7X          {'max_seats': 19, 'max_weight': 31750, 'max_di...
# Falcon 2000LXS     {'max_seats': 10, 'max_weight': 19105, 'max_di...
# SpaceJet M90                                                     NaN
# C919                                                             NaN
#
#                                                           Mitsubishi  \
# 737-800                                                          NaN
# 777-300ER                                                        NaN
# 787-9                                                            NaN
# A320neo                                                          NaN
# A350-900                                                         NaN
# A380-800                                                         NaN
# E190-E2                                                          NaN
# E175                                                             NaN
# E195-E2                                                          NaN
# CRJ900                                                           NaN
# Q400                                                             NaN
# Citation X+                                                      NaN
# Citation Latitude                                                NaN
# G650                                                             NaN
# G550                                                             NaN
# Falcon 7X                                                        NaN
# Falcon 2000LXS                                                   NaN
# SpaceJet M90       {'max_seats': 92, 'max_weight': 39000, 'max_di...
# C919                                                             NaN
#
#                                                                COMAC
# 737-800                                                          NaN
# 777-300ER                                                        NaN
# 787-9                                                            NaN
# A320neo                                                          NaN
# A350-900                                                         NaN
# A380-800                                                         NaN
# E190-E2                                                          NaN
# E175                                                             NaN
# E195-E2                                                          NaN
# CRJ900                                                           NaN
# Q400                                                             NaN
# Citation X+                                                      NaN
# Citation Latitude                                                NaN
# G650                                                             NaN
# G550                                                             NaN
# Falcon 7X                                                        NaN
# Falcon 2000LXS                                                   NaN
# SpaceJet M90                                                     NaN
# C919               {'max_seats': 174, 'max_weight': 72500, 'max_d...

# %%
import json

with open('../data/aeroplane_model.json') as f:
    d = json.load(f)
    print(d)
# Out:
# {'Boeing': {'737-800': {'max_seats': 189, 'max_weight': 79015, 'max_distance': 2935, 'engine_type': 'CFM56-7B'}, '777-300ER': {'max_seats': 396, 'max_weight': 351535, 'max_distance': 7930, 'engine_type': 'GE90-115B'}, '787-9': {'max_seats': 296, 'max_weight': 254000, 'max_distance': 7635, 'engine_type': 'GEnx-1B'}}, 'Airbus': {'A320neo': {'max_seats': 194, 'max_weight': 79000, 'max_distance': 3700, 'engine_type': 'CFM LEAP-1A'}, 'A350-900': {'max_seats': 440, 'max_weight': 280000, 'max_distance': 8100, 'engine_type': 'Rolls-Royce Trent XWB'}, 'A380-800': {'max_seats': 853, 'max_weight': 560000, 'max_distance': 8000, 'engine_type': 'Rolls-Royce Trent 900'}}, 'Embraer': {'E190-E2': {'max_seats': 114, 'max_weight': 56600, 'max_distance': 3250, 'engine_type': 'PW1900G'}, 'E175': {'max_seats': 88, 'max_weight': 37500, 'max_distance': 2200, 'engine_type': 'CF34-8E'}, 'E195-E2': {'max_seats': 146, 'max_weight': 61700, 'max_distance': 2600, 'engine_type': 'PW1900G'}}, 'Bombardier': {'CRJ900': {'max_seats': 90, 'max_weight': 38530, 'max_distance': 1554, 'engine_type': 'CF34-8C5'}, 'Q400': {'max_seats': 90, 'max_weight': 29257, 'max_distance': 1567, 'engine_type': 'PW150A'}}, 'Cessna': {'Citation X+': {'max_seats': 12, 'max_weight': 16555, 'max_distance': 3516, 'engine_type': 'AE3007C2'}, 'Citation Latitude': {'max_seats': 9, 'max_weight': 13605, 'max_distance': 2700, 'engine_type': 'PW306D1'}}, 'Gulfstream': {'G650': {'max_seats': 19, 'max_weight': 45360, 'max_distance': 7500, 'engine_type': 'BR725'}, 'G550': {'max_seats': 19, 'max_weight': 41300, 'max_distance': 6750, 'engine_type': 'BR710'}}, 'Dassault': {'Falcon 7X': {'max_seats': 19, 'max_weight': 31750, 'max_distance': 5950, 'engine_type': 'PW307A'}, 'Falcon 2000LXS': {'max_seats': 10, 'max_weight': 19105, 'max_distance': 4000, 'engine_type': 'PW308C'}}, 'Mitsubishi': {'SpaceJet M90': {'max_seats': 92, 'max_weight': 39000, 'max_distance': 2030, 'engine_type': 'PW1200G'}}, 'COMAC': {'C919': {'max_seats': 174, 'max_weight': 72500, 'max_distance': 2555, 'engine_type': 'CFM LEAP-1C'}}}

# %%
fleet = []

# %%
for item in d:
    aeroplane = {}
    print(item)
    aeroplane['type'] = item
    for indi in d[item]:
        aeroplane['series'] = indi
        aeroplane['max_seats'] = d[item][indi]['max_seats']
        aeroplane['max_weight'] = d[item][indi]['max_weight']
        aeroplane['max_distance'] = d[item][indi]['max_distance']
        aeroplane['engine_type'] = d[item][indi]['engine_type']
    fleet.append(aeroplane)
# Out:
# Boeing
# Airbus
# Embraer
# Bombardier
# Cessna
# Gulfstream
# Dassault
# Mitsubishi
# COMAC

# %%
fleet
# Out:
# [{'type': 'Boeing',
#   'series': '787-9',
#   'max_seats': 296,
#   'max_weight': 254000,
#   'max_distance': 7635,
#   'engine_type': 'GEnx-1B'},
#  {'type': 'Airbus',
#   'series': 'A380-800',
#   'max_seats': 853,
#   'max_weight': 560000,
#   'max_distance': 8000,
#   'engine_type': 'Rolls-Royce Trent 900'},
#  {'type': 'Embraer',
#   'series': 'E195-E2',
#   'max_seats': 146,
#   'max_weight': 61700,
#   'max_distance': 2600,
#   'engine_type': 'PW1900G'},
#  {'type': 'Bombardier',
#   'series': 'Q400',
#   'max_seats': 90,
#   'max_weight': 29257,
#   'max_distance': 1567,
#   'engine_type': 'PW150A'},
#  {'type': 'Cessna',
#   'series': 'Citation Latitude',
#   'max_seats': 9,
#   'max_weight': 13605,
#   'max_distance': 2700,
#   'engine_type': 'PW306D1'},
#  {'type': 'Gulfstream',
#   'series': 'G550',
#   'max_seats': 19,
#   'max_weight': 41300,
#   'max_distance': 6750,
#   'engine_type': 'BR710'},
#  {'type': 'Dassault',
#   'series': 'Falcon 2000LXS',
#   'max_seats': 10,
#   'max_weight': 19105,
#   'max_distance': 4000,
#   'engine_type': 'PW308C'},
#  {'type': 'Mitsubishi',
#   'series': 'SpaceJet M90',
#   'max_seats': 92,
#   'max_weight': 39000,
#   'max_distance': 2030,
#   'engine_type': 'PW1200G'},
#  {'type': 'COMAC',
#   'series': 'C919',
#   'max_seats': 174,
#   'max_weight': 72500,
#   'max_distance': 2555,
#   'engine_type': 'CFM LEAP-1C'}]

# %%
df = pd.DataFrame(fleet)
df
# Out:
#          type             series  max_seats  max_weight  max_distance  \
# 0      Boeing              787-9        296      254000          7635
# 1      Airbus           A380-800        853      560000          8000
# 2     Embraer            E195-E2        146       61700          2600
# 3  Bombardier               Q400         90       29257          1567
# 4      Cessna  Citation Latitude          9       13605          2700
# 5  Gulfstream               G550         19       41300          6750
# 6    Dassault     Falcon 2000LXS         10       19105          4000
# 7  Mitsubishi       SpaceJet M90         92       39000          2030
# 8       COMAC               C919        174       72500          2555
#
#              engine_type
# 0                GEnx-1B
# 1  Rolls-Royce Trent 900
# 2                PW1900G
# 3                 PW150A
# 4                PW306D1
# 5                  BR710
# 6                 PW308C
# 7                PW1200G
# 8            CFM LEAP-1C
